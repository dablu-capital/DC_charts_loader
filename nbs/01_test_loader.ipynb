# %%
from pathlib import Path
import pandas as pd
import sys

ROOT_DIR = Path().cwd().parent


if str(ROOT_DIR) not in sys.path:
    sys.path.insert(0, str(ROOT_DIR))

from src.data import load_daily_data
from src.models import ChartsDailyData

# %%
from src.config import config

dict_filename = f"../data/{config.general.data_filename}"
data_filename = dict_filename.replace(".feather", "_data.feather")

chart_data = ChartsDailyData(dict_filename, data_filename)
print("Charts loaded:", len(chart_data.charts))
# Out:
# Charts loaded: 3449

# %%
df,metadata = chart_data.load_chart(5)
df
# Out:
# metadata for daily chart: {'ticker': 'STSS', 'date_str': '2025-06-04', 'date': Timestamp('2025-06-04 00:00:00'), 'timeframe': '1D', 'index': 5}
#    ticker       date   open    high     low  close    volume  SMA_5
# 0    STSS 2025-05-05  4.630  4.7294  4.3350   4.65    107008    NaN
# 1    STSS 2025-05-06  5.160  5.3999  4.6500   4.70    233244    NaN
# 2    STSS 2025-05-07  4.650  4.8000  4.4500   4.66    147277    NaN
# 3    STSS 2025-05-08  4.670  5.1800  4.6700   5.05    174613    NaN
# 4    STSS 2025-05-09  5.050  5.1330  4.6800   4.73    157115  4.758
# 5    STSS 2025-05-12  4.670  4.7390  4.4635   4.66    135465  4.760
# 6    STSS 2025-05-13  4.650  4.6500  4.3500   4.55     84604  4.730
# 7    STSS 2025-05-14  4.680  4.8100  4.3700   4.56     97593  4.710
# 8    STSS 2025-05-15  4.550  4.5500  4.4156   4.51     50741  4.602
# 9    STSS 2025-05-16  4.430  4.5700  4.1501   4.57     76318  4.570
# 10   STSS 2025-05-19  4.200  4.3900  4.1205   4.28     92112  4.494
# ...

# %%
path = Path.cwd() / config.general.data_path
filename = config.general.data_filename
dict_filename = path / filename
min_data_filename = dict_filename.with_name(dict_filename.stem.replace(".feather", "") + "_min_data.feather")
print("Min data filename:", min_data_filename)
print("dict_filename:", dict_filename)
# Out:
# Min data filename: d:\Python\DC_charts_loader\nbs\data\0014_50_pct_gappers_20031008_20250606_min_data.feather
# dict_filename: d:\Python\DC_charts_loader\nbs\data\0014_50_pct_gappers_20031008_20250606.feather

# %%
from lightweight_charts import Chart
chart = Chart()
# chart.set(df.drop(columns=["ticker"]))
chart.set(df)
chart.watermark("Random Data Example")
chart.show(block=True)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 6
#       4 chart.set(df)
#       5 chart.watermark("Random Data Example")
# ----> 6 chart.show(block=True)
#
# File c:\Users\Lollo\anaconda3\envs\base312\Lib\site-packages\lightweight_charts\chart.py:202, in Chart.show(self, block)
#     200     Chart.WV.show(self._i)
#     201 if block:
# --> 202     asyncio.run(self.show_async())
#
# File c:\Users\Lollo\anaconda3\envs\base312\Lib\asyncio\runners.py:190, in run(main, debug, loop_factory)
#     161 """Execute the coroutine and return the result.
#     162
#     163 This function runs the passed coroutine, taking care of
#    (...)    186     asyncio.run(main())
#     187 """
#     188 if events._get_running_loop() is not None:
#     189     # fail fast with short traceback
# --> 190     raise RuntimeError(
# ...

# %%
for col in df.columns:
    if df[col].dtype == np.float32:
        df[col] = df[col].astype(np.float64)
        
df.dtypes
# Out:
# ticker          category
# date      datetime64[ns]
# open             float64
# high             float64
# low              float64
# close            float64
# volume             int64
# dtype: object

# %%
df = load_daily_data(ticker, date, df_data)
print("Loaded data shape:", df.shape)
print("Data sample:")
df
# Out:
# Loaded data shape: (81, 9)
# Data sample:
#    ticker       date       open       high        low      close    volume  \
# 0      AA 2016-09-12   9.520000   9.800000   9.430000   9.780000  21681919
# 1      AA 2016-09-12   9.520000   9.800000   9.430000   9.780000  21681919
# 2      AA 2016-09-13   9.630000   9.645000   9.450000   9.520000  18507673
# 3      AA 2016-09-13   9.630000   9.645000   9.450000   9.520000  18507673
# 4      AA 2016-09-14   9.690000   9.690000   9.360000   9.390000  15719147
# ..    ...        ...        ...        ...        ...        ...       ...
# 76     AA 2016-11-04  23.820000  25.500000  23.559999  25.200001   6878773
# 77     AA 2016-11-04  23.820000  25.500000  23.559999  25.200001   6878773
# 78     AA 2016-11-07  25.540001  26.410000  24.889999  25.080000   8377625
# 79     AA 2016-11-08  24.299999  26.590000  24.299999  26.400000   6471469
# 80     AA 2016-11-09  26.830000  29.139999  26.000000  28.719999  10676056
#
#     adjusted type
# ...
